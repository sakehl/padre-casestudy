# %%
res_solve = {
        "SolveDirectionHalide-CB.c" : ("Fail", "547"),
        "SolveDirectionHalide-CB-P.c" : ("Fail", "950"), # ????????
        "SolveDirectionHalide-NCB-L-P.c" : ("Fail", "1202")
}

# %%
res_sub = {
        "SubDirectionHalide-CB.c" : ("Succes", "180"),
        "SubDirectionHalide-NCB.c" : ("Fail", "534"),
        "SubDirectionHalide-NCB-L.c" : ("Succes", "693"),
        "SubDirectionHalide-NCB-L-P.c" : ("Fail", "248")
}

# %%
res_step = {
    "StepHalide-CB" : ("Succes", "57"),
    "StepHalide-NCB" : ("Fail", "96"),
    "StepHalide-CB-P" : ("Succes", "70"),
    "StepHalide-NCB-L-P" : ("Succes", "180")
}

# %% [markdown]
# # SolveDirection

# %%
# !vct SolveDirection/SolveDirectionHalide-CB.c
# Out:
# ...
# At /tmp/vercors-interpreted-12045430832254323437.i
# --------------------------------------
#   970           float *_cor_model_2_7 = (float *)__vercors_malloc(sizeof(float )*_262);
#   971           // produce cor_model_2
#                [-----
#   972           /*@
#   973            loop_invariant 0 <= _cor_model_2_s0_vis && _cor_model_2_s0_vis <= 0 + 230930;
#   974            loop_invariant (\forall* int _0; 0 <= _0 && _0 < 230930; Perm(&_ant1[_0], 1\2));
#        ... (77 lines omitted)
#  1052            float _312 = (float)(_311);
#  1053            _cor_model_2_7[_cor_model_2_s0_vis] = ((_307 * _309) + (_310 * _312));
#  1054           } // for _cor_model_2_s0_vis
#        ----------]
#  1055           {
#  1056            int _313 = 230930;
# --------------------------------------
# At SolveDirection/SolveDirectionHalide-CB.c
# --------------------------------------
#   687           float *_cor_model_2_7 = (float  *)malloc(sizeof(float )*_262);
# ...

# %%
# !vct SolveDirection/SolveDirectionHalide-CB.c
# Out:
# [mill-build/build.sc] [#06] [7/53] compileResources
# │  ======================================
# │  At /tmp/vercors-interpreted-3983470251514595341.i
# │  --------------------------------------
# │    987            loop_invariant (\forall* int _ … _2_s0_vis_forall], 1\1));
# │    988            loop_invariant (\forall* int _ … _2_s0_vis_forall], 1\1));
# │                                 [--------------- … -------------------------
# │    989            loop_invariant (\forall* int _ … _2_s0_vis_forall], 1\1));
# │                                  --------------- … ------------------------]
# │    990            loop_invariant (\forall* int _ … _2_s0_vis_forall], 1\1));
# │    991            loop_invariant (\forall* int _ … _2_s0_vis_forall], 1\1));
# │  --------------------------------------
# │  At SolveDirection/SolveDirectionHalide-CB.c
# │  --------------------------------------
# │    704            loop_invariant (\forall* int _ … _2_s0_vis_forall], 1\1));
# ...

# %%
((8*60+46)+(9*60+28))/2
# Out:
# 547.0

# %%
# !vct SolveDirection/SolveDirectionHalide-CB-P.c
# Out:
# [mill-build/build.sc] [#07] [8/53] enclosingClasspath
# VerCors › Verification › Proving › Task 1 › Verify … ontext ... 0 return 0; }`
# │  ======================================
# │  At side effect:
# │  --------------------------------------
# └─ [46.9%] Executing › !(corModel2S0V < 230930) ›  … 30 › numerator1S1Rv2X < 2
# ...
# [95.2%] [████████████████████████████████████████████████████████████████▉   ]
# VerCors › Verification › Proving › Task 1 › Verify … ontext ... 0 return 0; }`
# [95.2%] [████████████████████████████████████████████████████████████████▉   ]
# VerCors › Verification › Proving › Task 1
# ...
# At /tmp/vercors-interpreted-17438725558451306741.i
# --------------------------------------
#  4418                                      /*@ with
#  4419                                       unfold [1\2]cor_model_transp_1_3_pred(_cor_model_transp_1_3, _numerator__1_s1_rv2__y, 0, 230930); @*/
# ...

# %%
# !vct SolveDirection/SolveDirectionHalide-CB-P.c
# Out:
# [mill-build/build.sc] [#08] [9/53] resources.super.mill.scalalib.JavaModule.resources
# VerCors › Verification › Proving › Task 1 › Verify … ontext ... 0 return 0; }`
# │  ======================================
# │  At side effect:
# │  --------------------------------------
# └─ [46.9%] Executing › !(corModel2S0V < 230930) ›  … 30 › numerator1S1Rv2X < 2
# ...
# [95.2%] [████████████████████████████████████████████████████████████████▉   ]
# VerCors › Verification › Proving › Task 1 › Verify … › !(denominator1S0A < 50)
# [95.2%] [████████████████████████████████████████████████████████████████▉   ]
# VerCors › Verification › Proving › Task 1
# ...
# At /tmp/vercors-interpreted-10708018610026752839.i
# --------------------------------------
#  4432                                      /*@ with
#  4433                                       unfold [1\2]cor_model_transp_1_2_pred(_cor_model_transp_1_2, _numerator__1_s1_rv2__y, 0, 230930); @*/
# ...

# %%
((15*60+40) + (15*60)+59)/2
# Out:
# 949.5

# %%
# !vct SolveDirection/SolveDirectionHalide-NCB-L-P.c
# Out:
# [mill-build/build.sc] [#01] [2/53] cliImports
# [95.2%] [████████████████████████████████████████████████████████████████▉   ]
# VerCors › Verification › Proving › Task 1
# ...
# At /tmp/vercors-interpreted-9479790797305541325.i
# --------------------------------------
#  4515                                       _ant2[_numerator__1_s1_rv2__y]
#  4516                                      /*@ then
#                                            [----------------------------------
#  4517                                       fold [1\2]_ant2_pred_compl(_ant2); @*/
#                                             ----------------------------------]
#  4518                                      ;
#  4519                                      int _t7799_s = _531;
# --------------------------------------
# At SolveDirection/SolveDirectionHalide-NCB-L-P.c
# --------------------------------------
#  4232                                       _ant2[_numerator__1_s1_rv2__y]
# ...

# %%
# !vct SolveDirection/SolveDirectionHalide-NCB-L-P.c
# Out:
# [mill-build/build.sc] [#01] [2/53] cliImports
# VerCors › Verification › Proving › Task 1 › Verify … ontext ... 0 return 0; }`
# │  ======================================
# │  At side effect:
# │  --------------------------------------
# └─ [46.9%] Executing › !(corModel2S0V < 230930) ›  … 30 › numerator1S1Rv2X < 2
# ...
# [95.2%] [████████████████████████████████████████████████████████████████▉   ]
# VerCors › Verification › Proving › Task 1 › Verify … 2) › !(vRes0S0V < 230930)
# [95.2%] [████████████████████████████████████████████████████████████████▉   ]
# VerCors › Verification › Proving › Task 1
# ...
# At /tmp/vercors-interpreted-12592940474822534119.i
# --------------------------------------
#  4540                                      /*@ with
#  4541                                       unfold [1\2]_float64_pred(_sol_); @*/
#                                            [------------------------------------------
# ...

# %%
((22*60+21)+(17*60+43))/2
# Out:
# 1202.0

# %%
# !vct SolveDirection/SolveDirectionHalide-CB-P-V1.c
# Out:
# [mill-build/build.sc] [#01] [2/53] cliImports
# [71.4%] [████████████████████████████████████████████████▊                   ]
# VerCors › Transformation
# [71.4%] [████████████████████████████████████████████████▊                   ]
# VerCors › Transformation › adtOption
# [71.4%] [████████████████████████████████████████████████▊                   ]
# VerCors › Transformation
# [71.4%] [████████████████████████████████████████████████▊                   ]
# VerCors › Transformation › adtFrac
# [71.4%] [████████████████████████████████████████████████▊                   ]
# VerCors › Transformation
# [71.4%] [████████████████████████████████████████████████▊                   ]
# VerCors › Transformation › adtNothing
# [71.4%] [████████████████████████████████████████████████▊                   ]
# VerCors › Transformation
# [71.4%] [████████████████████████████████████████████████▊                   ]
# VerCors › Transformation › adtVoid
# ...

# %%
# !vct SolveDirection/SolveDirectionHalide-CB-P-V1.c
# Out:
# [mill-build/build.sc] [#06] [7/53] compileResources
# ...
# At /tmp/vercors-interpreted-9461124670460174886.i
# --------------------------------------
#  2734                } // for _denominator__1_s0_a
#  2735                // consume v_res0
#                     [-----
#  2736                /*@
#  2737                 loop_invariant 0 <= _denominator__1_s1_fused_rv2__y && _denominator__1_s1_fused_rv2__y <= 0 + 230930;
#  2738                 loop_invariant [1\2]_int32_pred(_ant1);
#        ... (4492 lines omitted)
#  7231                  } // alloc _cor_model_transp_1_1
#  7232                 } // alloc _cor_model_transp_1_0
#  7233                } // for _denominator__1_s1_fused_rv2__y
#        ---------------]
#  7234                /*@ ghost from_pred_v_res0_0(_v_res0_0, 0, 230930);
#  7235                 @*/
# --------------------------------------
# At SolveDirection/SolveDirectionHalide-CB-P-V1.c
# --------------------------------------
# ...

# %% [markdown]
# # SubDirection

# %%
# !vct SubDirection/SubDirectionHalide-CB.c
# Out:
# [mill-build/build.sc] [#01] [2/53] cliImports
# VerCors › Verification › Proving › Task 1 › Verify … ontext ... s return 0; }`
# │  ======================================
# │  At /tmp/vercors-interpreted-990368052660761459.i
# │  --------------------------------------
# │    715   context _v_res_out_buffer->dim[2].min = … ffer->dim[2].stride == 4;
# │    716   context _v_res_out_buffer->dim[3].min = … ffer->dim[3].stride == 8;
# │                 [------------------------------- … -------------------------
# │    717   context (\forall* int _0, int _1, int _ … _2*4 + _1*2 + _0], 1\1));
# │                  ------------------------------- … ------------------------]
# │    718   context_everywhere _solution_index0 >=  … _dir_sol <= _n_solutions;
# │    719   context_everywhere (\forall int _0; 0 < … ion_index0 + _n_dir_sol);
# │  --------------------------------------
# │  At SubDirection/SubDirectionHalide-CB.c
# │  --------------------------------------
# ...

# %%
# !vct SubDirection/SubDirectionHalide-CB.c
# Out:
# [mill-build/build.sc] [#06] [7/53] compileResources
# VerCors › Verification › Proving › Task 1 › Verify … ontext ... s return 0; }`
# │  ======================================
# │  At /tmp/vercors-interpreted-18360040795379696743.i
# │  --------------------------------------
# │    715   context _v_res_out_buffer->dim[2].min = … ffer->dim[2].stride == 4;
# │    716   context _v_res_out_buffer->dim[3].min = … ffer->dim[3].stride == 8;
# │                 [------------------------------- … -------------------------
# │    717   context (\forall* int _0, int _1, int _ … _2*4 + _1*2 + _0], 1\1));
# │                  ------------------------------- … ------------------------]
# │    718   context_everywhere _solution_index0 >=  … _dir_sol <= _n_solutions;
# │    719   context_everywhere (\forall int _0; 0 < … ion_index0 + _n_dir_sol);
# │  --------------------------------------
# │  At SubDirection/SubDirectionHalide-CB.c
# │  --------------------------------------
# ...

# %%
# !vct SubDirection/SubDirectionHalide-NCB.c
# Out:
# java.net.SocketException: Connection reset by peer
# 	at org.newsclub.net.unix.NativeUnixSocket.read(Native Method)
# 	at org.newsclub.net.unix.AFSocketImpl$AFInputStreamImpl.read(AFSocketImpl.java:517)
# 	at mill.main.client.ProxyStreamPumper.run(ProxyStreamPumper.java:28)
# 	at java.base/java.lang.Thread.run(Thread.java:840)

# %%
# !vct SubDirection/SubDirectionHalide-NCB.c
# Out:
# [mill-build/build.sc] [#00] [1/53] scriptSources
# VerCors › Verification › Proving › Task 1 › Verify … ontext ... s return 0; }`
# │  ======================================
# │  At side effect:
# │  --------------------------------------
# └─ [43.4%] Executing
# ...
#    │  ======================================
#    │  [unknown context]
#    │  --------------------------------------
#    └─ [42.1%] Exhaling
# ...
#       │  ======================================
#       │  [unknown context]
#       │  --------------------------------------
#       └─ [19.0%] Exhaling › vResOutS0Vis < nVis ›  … t2(_, flatten60@897@05)))
# ...
# [95.2%] [████████████████████████████████████████████████████████████████▉   ]
# VerCors › Verification › Proving › Task 1 › Verify … ontext ... s return 0; }`
# │  ======================================
# │  At side effect:
# │  --------------------------------------
# └─ [43.4%] Executing
# ...
#    │  ======================================
#    │  [unknown context]
# ...

# %%
8*60+54
# Out:
# 534

# %%
# !vct SubDirection/SubDirectionHalide-NCB-L.c
# Out:
# [mill-build/build.sc] [#00] [1/53] scriptSources
# [95.2%] [████████████████████████████████████████████████████████████████▉   ]
# VerCors › Verification › Proving › Task 1 › Verify … ontext ... s return 0; }`
# │  ======================================
# │  At /tmp/vercors-interpreted-13067732875905605994.i
# │  --------------------------------------
# │    737   context _v_res_out_buffer->dim[2].min = … ffer->dim[2].stride == 4;
# │    738   context _v_res_out_buffer->dim[3].min = … ffer->dim[3].stride == 8;
# │                 [------------------------------- … -------------------------
# │    739   context (\forall* int _0, int _1, int _ … _2*4 + _1*2 + _0], 1\1));
# │                  ------------------------------- … ------------------------]
# │    740   context_everywhere _solution_index0 >=  … _dir_sol <= _n_solutions;
# │    741   context_everywhere (\forall int _0; 0 < … ion_index0 + _n_dir_sol);
# │  --------------------------------------
# ...

# %%
# !vct SubDirection/SubDirectionHalide-NCB-L.c
# Out:
# [mill-build/build.sc] [#10] [11/53] mill.scalalib.ZincWorkerModule.zincLogDebug
# VerCors › Verification › Proving › Task 1 › Verify … ontext ... s return 0; }`
# │  ======================================
# │  [unknown context]
# │  --------------------------------------
# └─ [100.0%] Exhaling
# ...
#    │  ======================================
#    │  At /tmp/vercors-interpreted-4433294259789242664.i
#    │  --------------------------------------
#    │    737   context _v_res_out_buffer->dim[2].mi … ffer->dim[2].stride == 4;
#    │    738   context _v_res_out_buffer->dim[3].mi … ffer->dim[3].stride == 8;
#    │                 [---------------------------- … -------------------------
#    │    739   context (\forall* int _0, int _1, in … _2*4 + _1*2 + _0], 1\1));
#    │                  ---------------------------- … ------------------------]
#    │    740   context_everywhere _solution_index0  … _dir_sol <= _n_solutions;
# ...

# %%
(11*60+38+11*60+27)/2
# Out:
# 692.5

# %%
# !vct SubDirection/SubDirectionHalide-NCB-L-P.c
# Out:
# [mill-build/build.sc] [#07] [8/53] enclosingClasspath
# ...
# At /tmp/vercors-interpreted-1607289827741062460.i
# --------------------------------------
#  1697   context _ant1_buffer->dim[0].min == 0 && _ant1_buffer->dim[0].extent == _n_vis && _ant1_buffer->dim[0].stride == 1;
#  1698   context [1\2]_int32_pred(_ant1_buffer->host);
#                 [-------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  1699   requires (\forall int _0; 0 <= _0 && _0 < _n_vis; (\unfolding [1\2]_int32_pred(_ant1_buffer->host) \in 0 <= _ant1_buffer->host[_0] && _ant1_buffer->host[_0] < _n_antennas));
#                  -------------------------------------------------------------------------------------------------------------------------------------------------------------------]
# ...

# %%
# !vct SubDirection/SubDirectionHalide-NCB-L-P.c
# Out:
# [mill-build/build.sc] [#12] [13/53] sources.super.mill.scalalib.JavaModule.sources
# VerCors › Verification › Proving › Task 1
# ...
# At /tmp/vercors-interpreted-443192782998945011.i
# --------------------------------------
#  1697   context _ant1_buffer->dim[0].min == 0 && _ant1_buffer->dim[0].extent == _n_vis && _ant1_buffer->dim[0].stride == 1;
#  1698   context [1\2]_int32_pred(_ant1_buffer->host);
#                 [-------------------------------------------------------------------------------------------------------------------------------------------------------------------
#  1699   requires (\forall int _0; 0 <= _0 && _0 < _n_vis; (\unfolding [1\2]_int32_pred(_ant1_buffer->host) \in 0 <= _ant1_buffer->host[_0] && _ant1_buffer->host[_0] < _n_antennas));
#                  -------------------------------------------------------------------------------------------------------------------------------------------------------------------]
# ...

# %%
(3*60+6+5*60+10)/2
# Out:
# 248.0

# %% [markdown]
# # Step

# %%
# !vct Step/StepHalide-NCB-L-P.c
# Out:
# [mill-build/build.sc] [#10] [11/53] mill.scalalib.ZincWorkerModule.zincLogDebug
# ...
# [95.2%] [████████████████████████████████████████████████████████████████▉   ]
# VerCors › Verification › Proving › Task 1
# [INFO] Verification completed successfully.
# [95.2%] [████████████████████████████████████████████████████████████████▉   ]
# VerCors › Verification › Proving › Task 1
# [INFO] Finished verification at 01:22:20 (duration: 00:03:34)
# [95.2%] [████████████████████████████████████████████████████████████████▉   ]
# VerCors › Verification › Proving › Task 1

# %%
# !vct Step/StepHalide-NCB-L-P.c
# Out:
# [mill-build/build.sc] [#06] [7/53] compileResources
# At /tmp/vercors-interpreted-11049533232602170234.i
# --------------------------------------
#   592    data != NULL && \pointer_length(data) == c_extent * i_extent * si_extent * a_extent && lemma_4d_access(c, c_min, 1, c_extent, i, i_min, c_extent, i_extent, si, si_min, c_extent * i_extent, si_extent, a, a_min, c_extent * i_extent * si_extent, a_extent)) **
#   593    (\let int idx = (c-c_min)*1 + (i-i_min)*c_extent + (si-si_min)*c_extent * i_extent + (a-a_min)*c_extent * i_extent * si_extent;
#                [----
#   594     Perm(&data[idx], write));
#                 ----]
#   595
#   596   ghost
# --------------------------------------
# At Step/StepHalide-NCB-L-P.c
# --------------------------------------
# ...

# %%
# !vct Step/StepHalide-CB-L-P.c
# Out:
# [mill-build/build.sc] [#08] [9/53] resources.super.mill.scalalib.JavaModule.resources
# [INFO] Verification completed successfully.
# [95.2%] [████████████████████████████████████████████████████████████████▉   ]
# VerCors › Verification › Proving › Task 1 › Verify … ontext ... a return 0; }`
# │  ======================================
# │  At /tmp/vercors-interpreted-3726466589444177791.i
# │  --------------------------------------
# │    862   context _next_solutions__1_buffer->dim[ … ffer->dim[1].stride == 2;
# │    863   context _next_solutions__1_buffer->dim[ … ffer->dim[2].stride == 4;
# │                                                  … -------------------------
# │    864   context _next_solutions__1_buffer->dim[ … stride == _n_solutions*4;
# │                                                  … ------------------------]
# │    865   context (\forall* int _0, int _1, int _ … , _3, 0, _n_antennas):});
# │    866   context 0 < min(min(_n_antennas, _n_vis), _n_solutions);
# ...

# %%
# !vct Step/StepHalide-CB-L-P.c
# Out:
# [mill-build/build.sc] [#07] [8/53] enclosingClasspath
# [95.2%] [████████████████████████████████████████████████████████████████▉   ]
# VerCors › Verification › Proving › Task 1 › Verify … ontext ... a return 0; }`
# │  ======================================
# │  At /tmp/vercors-interpreted-12504159900190080484.i
# │  --------------------------------------
# │    863   context _next_solutions__1_buffer->dim[ … ffer->dim[2].stride == 4;
# │    864   context _next_solutions__1_buffer->dim[ … stride == _n_solutions*4;
# │                 [------------------------------- … -------------------------
# │    865   context (\forall* int _0, int _1, int _ … , _3, 0, _n_antennas):});
# │                  ------------------------------- … ------------------------]
# │    866   context 0 < min(min(_n_antennas, _n_vis), _n_solutions);
# │    867   context_everywhere _n_antennas == 50;
# │  --------------------------------------
# │  At Step/StepHalide-CB-L-P.c
# ...

# %%
(60+9+1*60+10)/2
# Out:
# 69.5

# %% [markdown]
# # PerformIterationHalide
